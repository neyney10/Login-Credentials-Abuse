# %% [markdown]
# # Synthetic data generator
# ## generation (04/10/2020), Version: 1

# %%
import pandas as pd
import numpy.random as rand
import numpy as np

# %% [markdown]
# ## Generate Users
# ### Load usernames and passwords from csv files

# %%
usernames_csv = pd.read_csv(r"D:\temp\Akamai\datasets\usernames\extracted archive.zip\users.csv", header=0, names=['Value', 'Count'], dtype={'Value': str, 'Count': 'int32'}, nrows=200000)
passwords_csv = pd.read_csv(r"D:\temp\Akamai\datasets\passwords\haveibeenpwned.csv", names=['Value','Count'], skiprows=1)
useragents_csv = pd.read_csv(r"D:\temp\Akamai\datasets\SCRIPTS\user-agents-strings-with-counts.csv", header=0, names=['Value', 'Count'], dtype={'Value': str, 'Count': 'int32'})

# %% [markdown]
# ### Some functions of samples

# %%
def uniform_sample(data, amount):
    return rand.choice(data['Value'], size=amount, replace=True)

def sample(data, distribution, amount):
    return rand.choice(data['Value'], size=amount, replace=True, p=distribution)

def unique_sample_replace(data, distribution, amount):
    return rand.choice(data['Value'], size=amount, replace=False, p=distribution)

def normal_distribution(size):
    nums = rand.default_rng().normal(1,1,size)
    nums = np.abs(nums)
    nums = nums/np.sum(nums)
    nums = -np.sort(-nums)
    return nums

# %% [markdown]
# ### Main function to generate users

# %%
def generate_users(usernames, passwords, amount):
    new_usernames = unique_sample_replace(usernames, usernames['Count']/np.sum(usernames['Count']), amount)
    new_passwords = sample(passwords, passwords['Count']/np.sum(passwords['Count']), amount)

    return pd.DataFrame({'username': new_usernames, 'password': new_passwords})

# %% [markdown]
# ### Start generating users.

# %%
amount_of_users = 20 *1000

users = generate_users(usernames_csv, passwords_csv, amount_of_users)

# %% [markdown]
# ## Generate authentication request records
# ### Functions of similr strings, for simulating typos of users when entring passwords

# %%
def get_replaced_letter_in_string(string, index, new_letter):
    separated_string = list(string)
    separated_string[index] = new_letter
    return "".join(separated_string)

def get_additional_letter_in_string(string, index, new_letter):
    separated_string = list(string)
    separated_string.insert(index, new_letter)
    return "".join(separated_string)

def get_removed_letter_in_string(string, index):
    separated_string = list(string)
    del separated_string[index]
    return "".join(separated_string)

def new_letter():
    letters = list('abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789')
    return rand.choice(letters)

def get_similar_string_of(string, other_passwords):
    change_type = rand.choice(["replace", "add", "rem", "other"], p=[0.4,0.25,0.25,0.1])
    similar_string = ""
    if change_type == "replace":
        similar_string = get_replaced_letter_in_string(string, rand.randint(0, len(string)), new_letter())
    elif change_type == "add":
        similar_string = get_additional_letter_in_string(string, rand.randint(0, len(string)), new_letter())
    elif change_type == "rem":
        similar_string = get_removed_letter_in_string(string, rand.randint(0, len(string)))
    elif change_type == "other":
        similar_string = rand.choice(other_passwords)

    return similar_string

# %% [markdown]
# ### Main Functions of generation of authentication requests

# %%
def shuffle_dataframe(df):
    return df.sample(frac=1).reset_index(drop=True)

def generate_authentication_requests_for_user(user, passwords, useragents, precentage_of_fail, request_times, onfail_function):
    chosen_useragents = unique_sample_replace(useragents, useragents['Count']/np.sum(useragents['Count']), np.random.binomial(3, 0.1, 1)[0]+1)

    requests = []
    for time in request_times:
        sent_useragent = rand.choice(chosen_useragents)
        outcome = rand.choice(['Success', 'Fail'], p=[1-precentage_of_fail, precentage_of_fail])
        if outcome == 'Success':
             sent_password = user['password']
        else:
            sent_password = onfail_function(user['password'], passwords['Value'])
        requests.append([time, user['username'], sent_password, sent_useragent, outcome])
    
    return requests

def generate_authentication_requests(users, passwords, useragents, precentage_of_fail, amount, max_time, onfail_function):
    rng = rand.default_rng()
    amount_of_users = len(users.index)

    requests = []
    while len(requests) < amount:
        users = shuffle_dataframe(users)

        for index, user in users.iterrows():
            print('Amount of requests created:', len(requests), len(requests)/amount)
            if amount <= len(requests):
                break
            amount_of_user_requests = rng.binomial(amount/amount_of_users-1, 0.6)+1
            if amount_of_user_requests > amount-len(requests):
                amount_of_user_requests = int(amount-len(requests))
            request_times = rand.randint(0, max_time, amount_of_user_requests)
            user_requests = generate_authentication_requests_for_user(user, passwords, useragents, precentage_of_fail, request_times, onfail_function)
            requests = requests + user_requests

    return pd.DataFrame(requests, columns=['Time', 'Username', 'Password', 'Useragent', 'Outcome'])

# %% [markdown]
# ### Start generating requests

# %%
precentage_of_fail = 0.01
amount_of_requests = 2* (10**6)
max_time = 500000

generated_requests = generate_authentication_requests(users, passwords_csv, useragents_csv, precentage_of_fail, amount_of_requests, max_time, lambda password, other_pass:  get_similar_string_of(password, other_pass)).sort_values('Time').reset_index()

len(generated_requests.index)
# Out:
# 86609
# Amount of requests created: 1973278 0.986639
# Amount of requests created: 1973333 0.9866665
# Amount of requests created: 1973394 0.986697
# Amount of requests created: 1973454 0.986727
# Amount of requests created: 1973510 0.986755
# Amount of requests created: 1973567 0.9867835
# Amount of requests created: 1973628 0.986814
# Amount of requests created: 1973686 0.986843
# Amount of requests created: 1973754 0.986877
# Amount of requests created: 1973814 0.986907
# Amount of requests created: 1973871 0.9869355
# Amount of requests created: 1973928 0.986964
# Amount of requests created: 1973989 0.9869945
# Amount of requests created: 1974048 0.987024
# Amount of requests created: 1974117 0.9870585
# Amount of requests created: 1974182 0.987091
# Amount of requests created: 1974233 0.9871165
# Amount of requests created: 1974294 0.987147
# Amount of requests created: 1974344 0.987172
# Amount of requests created: 1974404 0.987202
# Amount of requests created: 1974469 0.9872345
# Amount of requests created: 1974532 0.987266
# Amount of requests created: 1974591 0.9872955
# Amount of requests created: 1974647 0.9873235
# Amount of requests created: 1974708 0.987354
# Amount of requests created: 1974777 0.9873885
# Amount of requests created: 1974836 0.987418
# Amount of requests created: 1974900 0.98745
# Amount of requests created: 1974967 0.9874835
# Amount of requests created: 1975023 0.9875115
# Amount of requests created: 1975087 0.9875435
# Amount of requests created: 1975150 0.987575
# Amount of requests created: 1975213 0.9876065
# Amount of requests created: 1975279 0.9876395
# Amount of requests created: 1975345 0.9876725
# Amount of requests created: 1975403 0.9877015
# Amount of requests created: 1975468 0.987734
# Amount of requests created: 1975524 0.987762
# Amount of requests created: 1975575 0.9877875
# Amount of requests created: 1975634 0.987817
# Amount of requests created: 1975702 0.987851
# Amount of requests created: 1975762 0.987881
# Amount of requests created: 1975832 0.987916
# Amount of requests created: 1975891 0.9879455
# Amount of requests created: 1975943 0.9879715
# Amount of requests created: 1976000 0.988
# Amount of requests created: 1976052 0.988026
# Amount of requests created: 1976123 0.9880615
# Amount of requests created: 1976180 0.98809
# Amount of requests created: 1976237 0.9881185
# Amount of requests created: 1976294 0.988147
# Amount of requests created: 1976356 0.988178
# Amount of requests created: 1976418 0.988209
# Amount of requests created: 1976480 0.98824
# Amount of requests created: 1976540 0.98827
# Amount of requests created: 1976600 0.9883
# Amount of requests created: 1976654 0.988327
# Amount of requests created: 1976716 0.988358
# Amount of requests created: 1976780 0.98839
# Amount of requests created: 1976841 0.9884205
# Amount of requests created: 1976899 0.9884495
# Amount of requests created: 1976959 0.9884795
# Amount of requests created: 1977018 0.988509
# Amount of requests created: 1977075 0.9885375
# Amount of requests created: 1977131 0.9885655
# Amount of requests created: 1977193 0.9885965
# Amount of requests created: 1977260 0.98863
# Amount of requests created: 1977327 0.9886635
# Amount of requests created: 1977386 0.988693
# Amount of requests created: 1977442 0.988721
# Amount of requests created: 1977498 0.988749
# Amount of requests created: 1977550 0.988775
# Amount of requests created: 1977619 0.9888095
# Amount of requests created: 1977676 0.988838
# Amount of requests created: 1977738 0.988869
# Amount of requests created: 1977790 0.988895
# Amount of requests created: 1977841 0.9889205
# Amount of requests created: 1977905 0.9889525
# Amount of requests created: 1977968 0.988984
# Amount of requests created: 1978034 0.989017
# Amount of requests created: 1978099 0.9890495
# Amount of requests created: 1978162 0.989081
# Amount of requests created: 1978210 0.989105
# Amount of requests created: 1978272 0.989136
# Amount of requests created: 1978336 0.989168
# Amount of requests created: 1978394 0.989197
# Amount of requests created: 1978456 0.989228
# Amount of requests created: 1978517 0.9892585
# Amount of requests created: 1978575 0.9892875
# Amount of requests created: 1978628 0.989314
# Amount of requests created: 1978687 0.9893435
# Amount of requests created: 1978749 0.9893745
# Amount of requests created: 1978805 0.9894025
# Amount of requests created: 1978866 0.989433
# Amount of requests created: 1978931 0.9894655
# Amount of requests created: 1978992 0.989496
# Amount of requests created: 1979057 0.9895285
# Amount of requests created: 1979121 0.9895605
# Amount of requests created: 1979177 0.9895885
# Amount of requests created: 1979241 0.9896205
# Amount of requests created: 1979303 0.9896515
# Amount of requests created: 1979360 0.98968
# Amount of requests created: 1979421 0.9897105
# Amount of requests created: 1979483 0.9897415
# Amount of requests created: 1979541 0.9897705
# Amount of requests created: 1979604 0.989802
# Amount of requests created: 1979668 0.989834
# Amount of requests created: 1979721 0.9898605
# Amount of requests created: 1979772 0.989886
# Amount of requests created: 1979829 0.9899145
# Amount of requests created: 1979890 0.989945
# Amount of requests created: 1979943 0.9899715
# Amount of requests created: 1980003 0.9900015
# Amount of requests created: 1980061 0.9900305
# Amount of requests created: 1980116 0.990058
# Amount of requests created: 1980178 0.990089
# Amount of requests created: 1980248 0.990124
# Amount of requests created: 1980308 0.990154
# Amount of requests created: 1980372 0.990186
# Amount of requests created: 1980433 0.9902165
# Amount of requests created: 1980485 0.9902425
# Amount of requests created: 1980538 0.990269
# Amount of requests created: 1980594 0.990297
# Amount of requests created: 1980656 0.990328
# Amount of requests created: 1980715 0.9903575
# Amount of requests created: 1980778 0.990389
# Amount of requests created: 1980835 0.9904175
# Amount of requests created: 1980885 0.9904425
# Amount of requests created: 1980942 0.990471
# Amount of requests created: 1981005 0.9905025
# Amount of requests created: 1981071 0.9905355
# Amount of requests created: 1981130 0.990565
# Amount of requests created: 1981190 0.990595
# Amount of requests created: 1981258 0.990629
# Amount of requests created: 1981321 0.9906605
# Amount of requests created: 1981382 0.990691
# Amount of requests created: 1981438 0.990719
# Amount of requests created: 1981501 0.9907505
# Amount of requests created: 1981558 0.990779
# Amount of requests created: 1981620 0.99081
# Amount of requests created: 1981676 0.990838
# Amount of requests created: 1981735 0.9908675
# Amount of requests created: 1981800 0.9909
# Amount of requests created: 1981862 0.990931
# Amount of requests created: 1981928 0.990964
# Amount of requests created: 1981988 0.990994
# Amount of requests created: 1982050 0.991025
# Amount of requests created: 1982111 0.9910555
# Amount of requests created: 1982169 0.9910845
# Amount of requests created: 1982230 0.991115
# Amount of requests created: 1982300 0.99115
# Amount of requests created: 1982368 0.991184
# Amount of requests created: 1982431 0.9912155
# Amount of requests created: 1982484 0.991242
# Amount of requests created: 1982545 0.9912725
# Amount of requests created: 1982603 0.9913015
# Amount of requests created: 1982656 0.991328
# Amount of requests created: 1982721 0.9913605
# Amount of requests created: 1982780 0.99139
# Amount of requests created: 1982842 0.991421
# Amount of requests created: 1982905 0.9914525
# Amount of requests created: 1982970 0.991485
# Amount of requests created: 1983035 0.9915175
# Amount of requests created: 1983090 0.991545
# Amount of requests created: 1983148 0.991574
# Amount of requests created: 1983213 0.9916065
# Amount of requests created: 1983274 0.991637
# Amount of requests created: 1983332 0.991666
# Amount of requests created: 1983402 0.991701
# Amount of requests created: 1983464 0.991732
# Amount of requests created: 1983534 0.991767
# Amount of requests created: 1983586 0.991793
# Amount of requests created: 1983651 0.9918255
# Amount of requests created: 1983711 0.9918555
# Amount of requests created: 1983772 0.991886
# Amount of requests created: 1983841 0.9919205
# Amount of requests created: 1983903 0.9919515
# Amount of requests created: 1983972 0.991986
# Amount of requests created: 1984036 0.992018
# Amount of requests created: 1984100 0.99205
# Amount of requests created: 1984165 0.9920825
# Amount of requests created: 1984235 0.9921175
# Amount of requests created: 1984300 0.99215
# Amount of requests created: 1984357 0.9921785
# Amount of requests created: 1984423 0.9922115
# Amount of requests created: 1984484 0.992242
# Amount of requests created: 1984550 0.992275
# Amount of requests created: 1984603 0.9923015
# Amount of requests created: 1984660 0.99233
# Amount of requests created: 1984723 0.9923615
# Amount of requests created: 1984790 0.992395
# Amount of requests created: 1984853 0.9924265
# Amount of requests created: 1984908 0.992454
# Amount of requests created: 1984975 0.9924875
# Amount of requests created: 1985035 0.9925175
# Amount of requests created: 1985086 0.992543
# Amount of requests created: 1985150 0.992575
# Amount of requests created: 1985214 0.992607
# Amount of requests created: 1985272 0.992636
# Amount of requests created: 1985336 0.992668
# Amount of requests created: 1985391 0.9926955
# Amount of requests created: 1985451 0.9927255
# Amount of requests created: 1985519 0.9927595
# Amount of requests created: 1985570 0.992785
# Amount of requests created: 1985632 0.992816
# Amount of requests created: 1985683 0.9928415
# Amount of requests created: 1985745 0.9928725
# Amount of requests created: 1985802 0.992901
# Amount of requests created: 1985854 0.992927
# Amount of requests created: 1985918 0.992959
# Amount of requests created: 1985984 0.992992
# Amount of requests created: 1986053 0.9930265
# Amount of requests created: 1986116 0.993058
# Amount of requests created: 1986168 0.993084
# Amount of requests created: 1986234 0.993117
# Amount of requests created: 1986300 0.99315
# Amount of requests created: 1986364 0.993182
# Amount of requests created: 1986425 0.9932125
# Amount of requests created: 1986483 0.9932415
# Amount of requests created: 1986542 0.993271
# Amount of requests created: 1986607 0.9933035
# Amount of requests created: 1986660 0.99333
# Amount of requests created: 1986718 0.993359
# Amount of requests created: 1986776 0.993388
# Amount of requests created: 1986835 0.9934175
# Amount of requests created: 1986907 0.9934535
# Amount of requests created: 1986971 0.9934855
# Amount of requests created: 1987028 0.993514
# Amount of requests created: 1987090 0.993545
# Amount of requests created: 1987151 0.9935755
# Amount of requests created: 1987212 0.993606
# Amount of requests created: 1987273 0.9936365
# Amount of requests created: 1987331 0.9936655
# Amount of requests created: 1987400 0.9937
# Amount of requests created: 1987466 0.993733
# Amount of requests created: 1987523 0.9937615
# Amount of requests created: 1987591 0.9937955
# Amount of requests created: 1987651 0.9938255
# Amount of requests created: 1987706 0.993853
# Amount of requests created: 1987776 0.993888
# Amount of requests created: 1987838 0.993919
# Amount of requests created: 1987899 0.9939495
# Amount of requests created: 1987960 0.99398
# Amount of requests created: 1988017 0.9940085
# Amount of requests created: 1988078 0.994039
# Amount of requests created: 1988140 0.99407
# Amount of requests created: 1988200 0.9941
# Amount of requests created: 1988264 0.994132
# Amount of requests created: 1988322 0.994161
# Amount of requests created: 1988383 0.9941915
# Amount of requests created: 1988437 0.9942185
# Amount of requests created: 1988497 0.9942485
# Amount of requests created: 1988566 0.994283
# Amount of requests created: 1988627 0.9943135
# Amount of requests created: 1988689 0.9943445
# Amount of requests created: 1988748 0.994374
# Amount of requests created: 1988798 0.994399
# Amount of requests created: 1988854 0.994427
# Amount of requests created: 1988924 0.994462
# Amount of requests created: 1988985 0.9944925
# Amount of requests created: 1989044 0.994522
# Amount of requests created: 1989111 0.9945555
# Amount of requests created: 1989170 0.994585
# Amount of requests created: 1989234 0.994617
# Amount of requests created: 1989292 0.994646
# Amount of requests created: 1989353 0.9946765
# Amount of requests created: 1989423 0.9947115
# Amount of requests created: 1989487 0.9947435
# Amount of requests created: 1989546 0.994773
# Amount of requests created: 1989605 0.9948025
# Amount of requests created: 1989656 0.994828
# Amount of requests created: 1989723 0.9948615
# Amount of requests created: 1989784 0.994892
# Amount of requests created: 1989845 0.9949225
# Amount of requests created: 1989906 0.994953
# Amount of requests created: 1989963 0.9949815
# Amount of requests created: 1990023 0.9950115
# Amount of requests created: 1990077 0.9950385
# Amount of requests created: 1990140 0.99507
# Amount of requests created: 1990194 0.995097
# Amount of requests created: 1990261 0.9951305
# Amount of requests created: 1990317 0.9951585
# Amount of requests created: 1990372 0.995186
# Amount of requests created: 1990431 0.9952155
# Amount of requests created: 1990490 0.995245
# Amount of requests created: 1990562 0.995281
# Amount of requests created: 1990623 0.9953115
# Amount of requests created: 1990681 0.9953405
# Amount of requests created: 1990738 0.995369
# Amount of requests created: 1990802 0.995401
# Amount of requests created: 1990866 0.995433
# Amount of requests created: 1990928 0.995464
# Amount of requests created: 1990988 0.995494
# Amount of requests created: 1991050 0.995525
# Amount of requests created: 1991116 0.995558
# Amount of requests created: 1991181 0.9955905
# Amount of requests created: 1991248 0.995624
# Amount of requests created: 1991316 0.995658
# Amount of requests created: 1991377 0.9956885
# Amount of requests created: 1991443 0.9957215
# Amount of requests created: 1991508 0.995754
# Amount of requests created: 1991568 0.995784
# Amount of requests created: 1991629 0.9958145
# Amount of requests created: 1991686 0.995843
# Amount of requests created: 1991744 0.995872
# Amount of requests created: 1991801 0.9959005
# Amount of requests created: 1991859 0.9959295
# Amount of requests created: 1991921 0.9959605
# Amount of requests created: 1991977 0.9959885
# Amount of requests created: 1992042 0.996021
# Amount of requests created: 1992114 0.996057
# Amount of requests created: 1992171 0.9960855
# Amount of requests created: 1992245 0.9961225
# Amount of requests created: 1992294 0.996147
# Amount of requests created: 1992357 0.9961785
# Amount of requests created: 1992423 0.9962115
# Amount of requests created: 1992479 0.9962395
# Amount of requests created: 1992538 0.996269
# Amount of requests created: 1992605 0.9963025
# Amount of requests created: 1992658 0.996329
# Amount of requests created: 1992712 0.996356
# Amount of requests created: 1992773 0.9963865
# Amount of requests created: 1992834 0.996417
# Amount of requests created: 1992896 0.996448
# Amount of requests created: 1992954 0.996477
# Amount of requests created: 1993011 0.9965055
# Amount of requests created: 1993072 0.996536
# Amount of requests created: 1993131 0.9965655
# Amount of requests created: 1993197 0.9965985
# Amount of requests created: 1993263 0.9966315
# Amount of requests created: 1993331 0.9966655
# Amount of requests created: 1993394 0.996697
# Amount of requests created: 1993453 0.9967265
# Amount of requests created: 1993514 0.996757
# Amount of requests created: 1993574 0.996787
# Amount of requests created: 1993633 0.9968165
# Amount of requests created: 1993691 0.9968455
# Amount of requests created: 1993754 0.996877
# Amount of requests created: 1993810 0.996905
# Amount of requests created: 1993866 0.996933
# Amount of requests created: 1993934 0.996967
# Amount of requests created: 1993985 0.9969925
# Amount of requests created: 1994034 0.997017
# Amount of requests created: 1994089 0.9970445
# Amount of requests created: 1994148 0.997074
# Amount of requests created: 1994211 0.9971055
# Amount of requests created: 1994268 0.997134
# Amount of requests created: 1994335 0.9971675
# Amount of requests created: 1994400 0.9972
# Amount of requests created: 1994454 0.997227
# Amount of requests created: 1994529 0.9972645
# Amount of requests created: 1994592 0.997296
# Amount of requests created: 1994645 0.9973225
# Amount of requests created: 1994707 0.9973535
# Amount of requests created: 1994768 0.997384
# Amount of requests created: 1994830 0.997415
# Amount of requests created: 1994892 0.997446
# Amount of requests created: 1994963 0.9974815
# Amount of requests created: 1995021 0.9975105
# Amount of requests created: 1995082 0.997541
# Amount of requests created: 1995152 0.997576
# Amount of requests created: 1995204 0.997602
# Amount of requests created: 1995270 0.997635
# Amount of requests created: 1995328 0.997664
# Amount of requests created: 1995386 0.997693
# Amount of requests created: 1995449 0.9977245
# Amount of requests created: 1995509 0.9977545
# Amount of requests created: 1995567 0.9977835
# Amount of requests created: 1995631 0.9978155
# Amount of requests created: 1995690 0.997845
# Amount of requests created: 1995750 0.997875
# Amount of requests created: 1995818 0.997909
# Amount of requests created: 1995878 0.997939
# Amount of requests created: 1995944 0.997972
# Amount of requests created: 1996010 0.998005
# Amount of requests created: 1996060 0.99803
# Amount of requests created: 1996120 0.99806
# Amount of requests created: 1996176 0.998088
# Amount of requests created: 1996238 0.998119
# Amount of requests created: 1996303 0.9981515
# Amount of requests created: 1996366 0.998183
# Amount of requests created: 1996436 0.998218
# Amount of requests created: 1996495 0.9982475
# Amount of requests created: 1996559 0.9982795
# Amount of requests created: 1996618 0.998309
# Amount of requests created: 1996673 0.9983365
# Amount of requests created: 1996730 0.998365
# Amount of requests created: 1996801 0.9984005
# Amount of requests created: 1996863 0.9984315
# Amount of requests created: 1996920 0.99846
# Amount of requests created: 1996975 0.9984875
# Amount of requests created: 1997031 0.9985155
# Amount of requests created: 1997088 0.998544
# Amount of requests created: 1997146 0.998573
# Amount of requests created: 1997205 0.9986025
# Amount of requests created: 1997261 0.9986305
# Amount of requests created: 1997323 0.9986615
# Amount of requests created: 1997388 0.998694
# Amount of requests created: 1997452 0.998726
# Amount of requests created: 1997514 0.998757
# Amount of requests created: 1997575 0.9987875
# Amount of requests created: 1997636 0.998818
# Amount of requests created: 1997695 0.9988475
# Amount of requests created: 1997749 0.9988745
# Amount of requests created: 1997810 0.998905
# Amount of requests created: 1997866 0.998933
# Amount of requests created: 1997922 0.998961
# Amount of requests created: 1997983 0.9989915
# Amount of requests created: 1998047 0.9990235
# Amount of requests created: 1998111 0.9990555
# Amount of requests created: 1998168 0.999084
# Amount of requests created: 1998229 0.9991145
# Amount of requests created: 1998287 0.9991435
# Amount of requests created: 1998351 0.9991755
# Amount of requests created: 1998413 0.9992065
# Amount of requests created: 1998483 0.9992415
# Amount of requests created: 1998538 0.999269
# Amount of requests created: 1998607 0.9993035
# Amount of requests created: 1998664 0.999332
# Amount of requests created: 1998721 0.9993605
# Amount of requests created: 1998776 0.999388
# Amount of requests created: 1998830 0.999415
# Amount of requests created: 1998896 0.999448
# Amount of requests created: 1998961 0.9994805
# Amount of requests created: 1999020 0.99951
# Amount of requests created: 1999086 0.999543
# Amount of requests created: 1999144 0.999572
# Amount of requests created: 1999205 0.9996025
# Amount of requests created: 1999266 0.999633
# Amount of requests created: 1999330 0.999665
# Amount of requests created: 1999390 0.999695
# Amount of requests created: 1999451 0.9997255
# Amount of requests created: 1999512 0.999756
# Amount of requests created: 1999581 0.9997905
# Amount of requests created: 1999640 0.99982
# Amount of requests created: 1999712 0.999856
# Amount of requests created: 1999776 0.999888
# Amount of requests created: 1999836 0.999918
# Amount of requests created: 1999903 0.9999515
# Amount of requests created: 1999964 0.999982
# Amount of requests created: 2000000 1.0
# 2000000

# %% [markdown]
# ### Generating malicious requests

# %%
def get_mal_pass_distribution(size):
    nums = np.full(size, 1)
    nums = nums/size
    return nums


precentage_of_fail_mal = 0.98
amount_of_requests_mal = 0.4* (10**6)
max_time_mal = 350000
password_list_mal = passwords_csv[passwords_csv.index.isin(np.arange(100))] # top 100 passwords
password_distribution_mal = get_mal_pass_distribution(100)
fraction_of_users_known_to_mal = 0.2
users_mal = users.sample(frac=fraction_of_users_known_to_mal)
useragents_mal = useragents_csv[useragents_csv.index.isin(np.arange(75))]

generated_requests_mal = generate_authentication_requests(users_mal, password_list_mal, useragents_mal, precentage_of_fail_mal, amount_of_requests_mal, max_time_mal, lambda password, other_pass:  rand.choice(other_pass, p=password_distribution_mal)).sort_values('Time').reset_index()

len(generated_requests_mal.index)
# Out:
# uests created: 372637 0.9315925
# Amount of requests created: 372698 0.931745
# Amount of requests created: 372757 0.9318925
# Amount of requests created: 372820 0.93205
# Amount of requests created: 372883 0.9322075
# Amount of requests created: 372945 0.9323625
# Amount of requests created: 373002 0.932505
# Amount of requests created: 373068 0.93267
# Amount of requests created: 373121 0.9328025
# Amount of requests created: 373183 0.9329575
# Amount of requests created: 373240 0.9331
# Amount of requests created: 373300 0.93325
# Amount of requests created: 373356 0.93339
# Amount of requests created: 373420 0.93355
# Amount of requests created: 373491 0.9337275
# Amount of requests created: 373551 0.9338775
# Amount of requests created: 373598 0.933995
# Amount of requests created: 373657 0.9341425
# Amount of requests created: 373709 0.9342725
# Amount of requests created: 373778 0.934445
# Amount of requests created: 373840 0.9346
# Amount of requests created: 373898 0.934745
# Amount of requests created: 373954 0.934885
# Amount of requests created: 374020 0.93505
# Amount of requests created: 374078 0.935195
# Amount of requests created: 374143 0.9353575
# Amount of requests created: 374212 0.93553
# Amount of requests created: 374276 0.93569
# Amount of requests created: 374334 0.935835
# Amount of requests created: 374397 0.9359925
# Amount of requests created: 374453 0.9361325
# Amount of requests created: 374513 0.9362825
# Amount of requests created: 374576 0.93644
# Amount of requests created: 374636 0.93659
# Amount of requests created: 374698 0.936745
# Amount of requests created: 374757 0.9368925
# Amount of requests created: 374807 0.9370175
# Amount of requests created: 374859 0.9371475
# Amount of requests created: 374914 0.937285
# Amount of requests created: 374978 0.937445
# Amount of requests created: 375040 0.9376
# Amount of requests created: 375098 0.937745
# Amount of requests created: 375148 0.93787
# Amount of requests created: 375208 0.93802
# Amount of requests created: 375271 0.9381775
# Amount of requests created: 375333 0.9383325
# Amount of requests created: 375391 0.9384775
# Amount of requests created: 375446 0.938615
# Amount of requests created: 375514 0.938785
# Amount of requests created: 375567 0.9389175
# Amount of requests created: 375624 0.93906
# Amount of requests created: 375691 0.9392275
# Amount of requests created: 375754 0.939385
# Amount of requests created: 375821 0.9395525
# Amount of requests created: 375884 0.93971
# Amount of requests created: 375937 0.9398425
# Amount of requests created: 376002 0.940005
# Amount of requests created: 376066 0.940165
# Amount of requests created: 376130 0.940325
# Amount of requests created: 376191 0.9404775
# Amount of requests created: 376246 0.940615
# Amount of requests created: 376309 0.9407725
# Amount of requests created: 376368 0.94092
# Amount of requests created: 376437 0.9410925
# Amount of requests created: 376493 0.9412325
# Amount of requests created: 376551 0.9413775
# Amount of requests created: 376607 0.9415175
# Amount of requests created: 376677 0.9416925
# Amount of requests created: 376741 0.9418525
# Amount of requests created: 376803 0.9420075
# Amount of requests created: 376868 0.94217
# Amount of requests created: 376932 0.94233
# Amount of requests created: 376994 0.942485
# Amount of requests created: 377050 0.942625
# Amount of requests created: 377112 0.94278
# Amount of requests created: 377174 0.942935
# Amount of requests created: 377234 0.943085
# Amount of requests created: 377290 0.943225
# Amount of requests created: 377347 0.9433675
# Amount of requests created: 377409 0.9435225
# Amount of requests created: 377470 0.943675
# Amount of requests created: 377525 0.9438125
# Amount of requests created: 377587 0.9439675
# Amount of requests created: 377639 0.9440975
# Amount of requests created: 377699 0.9442475
# Amount of requests created: 377762 0.944405
# Amount of requests created: 377807 0.9445175
# Amount of requests created: 377861 0.9446525
# Amount of requests created: 377925 0.9448125
# Amount of requests created: 377982 0.944955
# Amount of requests created: 378048 0.94512
# Amount of requests created: 378115 0.9452875
# Amount of requests created: 378179 0.9454475
# Amount of requests created: 378234 0.945585
# Amount of requests created: 378303 0.9457575
# Amount of requests created: 378365 0.9459125
# Amount of requests created: 378424 0.94606
# Amount of requests created: 378489 0.9462225
# Amount of requests created: 378542 0.946355
# Amount of requests created: 378606 0.946515
# Amount of requests created: 378676 0.94669
# Amount of requests created: 378737 0.9468425
# Amount of requests created: 378793 0.9469825
# Amount of requests created: 378854 0.947135
# Amount of requests created: 378915 0.9472875
# Amount of requests created: 378977 0.9474425
# Amount of requests created: 379033 0.9475825
# Amount of requests created: 379095 0.9477375
# Amount of requests created: 379156 0.94789
# Amount of requests created: 379217 0.9480425
# Amount of requests created: 379281 0.9482025
# Amount of requests created: 379352 0.94838
# Amount of requests created: 379416 0.94854
# Amount of requests created: 379478 0.948695
# Amount of requests created: 379537 0.9488425
# Amount of requests created: 379594 0.948985
# Amount of requests created: 379658 0.949145
# Amount of requests created: 379726 0.949315
# Amount of requests created: 379789 0.9494725
# Amount of requests created: 379859 0.9496475
# Amount of requests created: 379921 0.9498025
# Amount of requests created: 379983 0.9499575
# Amount of requests created: 380047 0.9501175
# Amount of requests created: 380101 0.9502525
# Amount of requests created: 380166 0.950415
# Amount of requests created: 380221 0.9505525
# Amount of requests created: 380283 0.9507075
# Amount of requests created: 380343 0.9508575
# Amount of requests created: 380403 0.9510075
# Amount of requests created: 380455 0.9511375
# Amount of requests created: 380513 0.9512825
# Amount of requests created: 380573 0.9514325
# Amount of requests created: 380637 0.9515925
# Amount of requests created: 380692 0.95173
# Amount of requests created: 380754 0.951885
# Amount of requests created: 380818 0.952045
# Amount of requests created: 380879 0.9521975
# Amount of requests created: 380931 0.9523275
# Amount of requests created: 380989 0.9524725
# Amount of requests created: 381054 0.952635
# Amount of requests created: 381115 0.9527875
# Amount of requests created: 381164 0.95291
# Amount of requests created: 381216 0.95304
# Amount of requests created: 381278 0.953195
# Amount of requests created: 381333 0.9533325
# Amount of requests created: 381396 0.95349
# Amount of requests created: 381452 0.95363
# Amount of requests created: 381513 0.9537825
# Amount of requests created: 381575 0.9539375
# Amount of requests created: 381638 0.954095
# Amount of requests created: 381694 0.954235
# Amount of requests created: 381750 0.954375
# Amount of requests created: 381810 0.954525
# Amount of requests created: 381874 0.954685
# Amount of requests created: 381933 0.9548325
# Amount of requests created: 381996 0.95499
# Amount of requests created: 382054 0.955135
# Amount of requests created: 382116 0.95529
# Amount of requests created: 382180 0.95545
# Amount of requests created: 382249 0.9556225
# Amount of requests created: 382305 0.9557625
# Amount of requests created: 382361 0.9559025
# Amount of requests created: 382415 0.9560375
# Amount of requests created: 382477 0.9561925
# Amount of requests created: 382535 0.9563375
# Amount of requests created: 382602 0.956505
# Amount of requests created: 382655 0.9566375
# Amount of requests created: 382719 0.9567975
# Amount of requests created: 382783 0.9569575
# Amount of requests created: 382841 0.9571025
# Amount of requests created: 382910 0.957275
# Amount of requests created: 382974 0.957435
# Amount of requests created: 383035 0.9575875
# Amount of requests created: 383102 0.957755
# Amount of requests created: 383163 0.9579075
# Amount of requests created: 383217 0.9580425
# Amount of requests created: 383275 0.9581875
# Amount of requests created: 383342 0.958355
# Amount of requests created: 383403 0.9585075
# Amount of requests created: 383465 0.9586625
# Amount of requests created: 383518 0.958795
# Amount of requests created: 383573 0.9589325
# Amount of requests created: 383639 0.9590975
# Amount of requests created: 383706 0.959265
# Amount of requests created: 383771 0.9594275
# Amount of requests created: 383827 0.9595675
# Amount of requests created: 383888 0.95972
# Amount of requests created: 383946 0.959865
# Amount of requests created: 384011 0.9600275
# Amount of requests created: 384076 0.96019
# Amount of requests created: 384146 0.960365
# Amount of requests created: 384204 0.96051
# Amount of requests created: 384267 0.9606675
# Amount of requests created: 384313 0.9607825
# Amount of requests created: 384378 0.960945
# Amount of requests created: 384430 0.961075
# Amount of requests created: 384488 0.96122
# Amount of requests created: 384551 0.9613775
# Amount of requests created: 384616 0.96154
# Amount of requests created: 384681 0.9617025
# Amount of requests created: 384741 0.9618525
# Amount of requests created: 384807 0.9620175
# Amount of requests created: 384865 0.9621625
# Amount of requests created: 384922 0.962305
# Amount of requests created: 384989 0.9624725
# Amount of requests created: 385053 0.9626325
# Amount of requests created: 385109 0.9627725
# Amount of requests created: 385160 0.9629
# Amount of requests created: 385217 0.9630425
# Amount of requests created: 385277 0.9631925
# Amount of requests created: 385340 0.96335
# Amount of requests created: 385402 0.963505
# Amount of requests created: 385463 0.9636575
# Amount of requests created: 385532 0.96383
# Amount of requests created: 385597 0.9639925
# Amount of requests created: 385658 0.964145
# Amount of requests created: 385723 0.9643075
# Amount of requests created: 385783 0.9644575
# Amount of requests created: 385830 0.964575
# Amount of requests created: 385891 0.9647275
# Amount of requests created: 385947 0.9648675
# Amount of requests created: 386014 0.965035
# Amount of requests created: 386080 0.9652
# Amount of requests created: 386141 0.9653525
# Amount of requests created: 386208 0.96552
# Amount of requests created: 386273 0.9656825
# Amount of requests created: 386326 0.965815
# Amount of requests created: 386393 0.9659825
# Amount of requests created: 386451 0.9661275
# Amount of requests created: 386505 0.9662625
# Amount of requests created: 386563 0.9664075
# Amount of requests created: 386632 0.96658
# Amount of requests created: 386692 0.96673
# Amount of requests created: 386753 0.9668825
# Amount of requests created: 386810 0.967025
# Amount of requests created: 386869 0.9671725
# Amount of requests created: 386930 0.967325
# Amount of requests created: 386991 0.9674775
# Amount of requests created: 387054 0.967635
# Amount of requests created: 387108 0.96777
# Amount of requests created: 387167 0.9679175
# Amount of requests created: 387229 0.9680725
# Amount of requests created: 387292 0.96823
# Amount of requests created: 387357 0.9683925
# Amount of requests created: 387422 0.968555
# Amount of requests created: 387480 0.9687
# Amount of requests created: 387539 0.9688475
# Amount of requests created: 387596 0.96899
# Amount of requests created: 387654 0.969135
# Amount of requests created: 387719 0.9692975
# Amount of requests created: 387775 0.9694375
# Amount of requests created: 387839 0.9695975
# Amount of requests created: 387894 0.969735
# Amount of requests created: 387958 0.969895
# Amount of requests created: 388020 0.97005
# Amount of requests created: 388088 0.97022
# Amount of requests created: 388153 0.9703825
# Amount of requests created: 388209 0.9705225
# Amount of requests created: 388268 0.97067
# Amount of requests created: 388333 0.9708325
# Amount of requests created: 388392 0.97098
# Amount of requests created: 388446 0.971115
# Amount of requests created: 388519 0.9712975
# Amount of requests created: 388591 0.9714775
# Amount of requests created: 388652 0.97163
# Amount of requests created: 388712 0.97178
# Amount of requests created: 388773 0.9719325
# Amount of requests created: 388822 0.972055
# Amount of requests created: 388889 0.9722225
# Amount of requests created: 388948 0.97237
# Amount of requests created: 389004 0.97251
# Amount of requests created: 389060 0.97265
# Amount of requests created: 389123 0.9728075
# Amount of requests created: 389186 0.972965
# Amount of requests created: 389237 0.9730925
# Amount of requests created: 389297 0.9732425
# Amount of requests created: 389364 0.97341
# Amount of requests created: 389425 0.9735625
# Amount of requests created: 389498 0.973745
# Amount of requests created: 389556 0.97389
# Amount of requests created: 389621 0.9740525
# Amount of requests created: 389682 0.974205
# Amount of requests created: 389749 0.9743725
# Amount of requests created: 389811 0.9745275
# Amount of requests created: 389872 0.97468
# Amount of requests created: 389931 0.9748275
# Amount of requests created: 389995 0.9749875
# Amount of requests created: 390048 0.97512
# Amount of requests created: 390114 0.975285
# Amount of requests created: 390169 0.9754225
# Amount of requests created: 390228 0.97557
# Amount of requests created: 390286 0.975715
# Amount of requests created: 390358 0.975895
# Amount of requests created: 390415 0.9760375
# Amount of requests created: 390474 0.976185
# Amount of requests created: 390530 0.976325
# Amount of requests created: 390595 0.9764875
# Amount of requests created: 390659 0.9766475
# Amount of requests created: 390720 0.9768
# Amount of requests created: 390783 0.9769575
# Amount of requests created: 390846 0.977115
# Amount of requests created: 390912 0.97728
# Amount of requests created: 390979 0.9774475
# Amount of requests created: 391048 0.97762
# Amount of requests created: 391109 0.9777725
# Amount of requests created: 391171 0.9779275
# Amount of requests created: 391230 0.978075
# Amount of requests created: 391291 0.9782275
# Amount of requests created: 391353 0.9783825
# Amount of requests created: 391413 0.9785325
# Amount of requests created: 391473 0.9786825
# Amount of requests created: 391529 0.9788225
# Amount of requests created: 391589 0.9789725
# Amount of requests created: 391653 0.9791325
# Amount of requests created: 391715 0.9792875
# Amount of requests created: 391778 0.979445
# Amount of requests created: 391840 0.9796
# Amount of requests created: 391896 0.97974
# Amount of requests created: 391960 0.9799
# Amount of requests created: 392008 0.98002
# Amount of requests created: 392069 0.9801725
# Amount of requests created: 392128 0.98032
# Amount of requests created: 392192 0.98048
# Amount of requests created: 392252 0.98063
# Amount of requests created: 392319 0.9807975
# Amount of requests created: 392379 0.9809475
# Amount of requests created: 392441 0.9811025
# Amount of requests created: 392497 0.9812425
# Amount of requests created: 392552 0.98138
# Amount of requests created: 392614 0.981535
# Amount of requests created: 392668 0.98167
# Amount of requests created: 392727 0.9818175
# Amount of requests created: 392777 0.9819425
# Amount of requests created: 392833 0.9820825
# Amount of requests created: 392891 0.9822275
# Amount of requests created: 392956 0.98239
# Amount of requests created: 393016 0.98254
# Amount of requests created: 393083 0.9827075
# Amount of requests created: 393145 0.9828625
# Amount of requests created: 393209 0.9830225
# Amount of requests created: 393263 0.9831575
# Amount of requests created: 393323 0.9833075
# Amount of requests created: 393383 0.9834575
# Amount of requests created: 393447 0.9836175
# Amount of requests created: 393507 0.9837675
# Amount of requests created: 393561 0.9839025
# Amount of requests created: 393628 0.98407
# Amount of requests created: 393689 0.9842225
# Amount of requests created: 393746 0.984365
# Amount of requests created: 393807 0.9845175
# Amount of requests created: 393868 0.98467
# Amount of requests created: 393925 0.9848125
# Amount of requests created: 393988 0.98497
# Amount of requests created: 394047 0.9851175
# Amount of requests created: 394112 0.98528
# Amount of requests created: 394179 0.9854475
# Amount of requests created: 394244 0.98561
# Amount of requests created: 394307 0.9857675
# Amount of requests created: 394363 0.9859075
# Amount of requests created: 394418 0.986045
# Amount of requests created: 394483 0.9862075
# Amount of requests created: 394543 0.9863575
# Amount of requests created: 394605 0.9865125
# Amount of requests created: 394661 0.9866525
# Amount of requests created: 394728 0.98682
# Amount of requests created: 394791 0.9869775
# Amount of requests created: 394856 0.98714
# Amount of requests created: 394918 0.987295
# Amount of requests created: 394979 0.9874475
# Amount of requests created: 395037 0.9875925
# Amount of requests created: 395093 0.9877325
# Amount of requests created: 395152 0.98788
# Amount of requests created: 395213 0.9880325
# Amount of requests created: 395281 0.9882025
# Amount of requests created: 395343 0.9883575
# Amount of requests created: 395397 0.9884925
# Amount of requests created: 395456 0.98864
# Amount of requests created: 395514 0.988785
# Amount of requests created: 395577 0.9889425
# Amount of requests created: 395635 0.9890875
# Amount of requests created: 395697 0.9892425
# Amount of requests created: 395754 0.989385
# Amount of requests created: 395816 0.98954
# Amount of requests created: 395875 0.9896875
# Amount of requests created: 395931 0.9898275
# Amount of requests created: 395982 0.989955
# Amount of requests created: 396046 0.990115
# Amount of requests created: 396116 0.99029
# Amount of requests created: 396187 0.9904675
# Amount of requests created: 396243 0.9906075
# Amount of requests created: 396303 0.9907575
# Amount of requests created: 396370 0.990925
# Amount of requests created: 396430 0.991075
# Amount of requests created: 396493 0.9912325
# Amount of requests created: 396552 0.99138
# Amount of requests created: 396615 0.9915375
# Amount of requests created: 396674 0.991685
# Amount of requests created: 396734 0.991835
# Amount of requests created: 396803 0.9920075
# Amount of requests created: 396857 0.9921425
# Amount of requests created: 396924 0.99231
# Amount of requests created: 396987 0.9924675
# Amount of requests created: 397043 0.9926075
# Amount of requests created: 397110 0.992775
# Amount of requests created: 397168 0.99292
# Amount of requests created: 397221 0.9930525
# Amount of requests created: 397286 0.993215
# Amount of requests created: 397349 0.9933725
# Amount of requests created: 397405 0.9935125
# Amount of requests created: 397470 0.993675
# Amount of requests created: 397533 0.9938325
# Amount of requests created: 397585 0.9939625
# Amount of requests created: 397647 0.9941175
# Amount of requests created: 397700 0.99425
# Amount of requests created: 397757 0.9943925
# Amount of requests created: 397819 0.9945475
# Amount of requests created: 397883 0.9947075
# Amount of requests created: 397943 0.9948575
# Amount of requests created: 398006 0.995015
# Amount of requests created: 398068 0.99517
# Amount of requests created: 398126 0.995315
# Amount of requests created: 398187 0.9954675
# Amount of requests created: 398248 0.99562
# Amount of requests created: 398317 0.9957925
# Amount of requests created: 398373 0.9959325
# Amount of requests created: 398429 0.9960725
# Amount of requests created: 398498 0.996245
# Amount of requests created: 398561 0.9964025
# Amount of requests created: 398617 0.9965425
# Amount of requests created: 398672 0.99668
# Amount of requests created: 398733 0.9968325
# Amount of requests created: 398791 0.9969775
# Amount of requests created: 398854 0.997135
# Amount of requests created: 398922 0.997305
# Amount of requests created: 398984 0.99746
# Amount of requests created: 399048 0.99762
# Amount of requests created: 399108 0.99777
# Amount of requests created: 399171 0.9979275
# Amount of requests created: 399227 0.9980675
# Amount of requests created: 399286 0.998215
# Amount of requests created: 399343 0.9983575
# Amount of requests created: 399402 0.998505
# Amount of requests created: 399460 0.99865
# Amount of requests created: 399522 0.998805
# Amount of requests created: 399579 0.9989475
# Amount of requests created: 399640 0.9991
# Amount of requests created: 399705 0.9992625
# Amount of requests created: 399769 0.9994225
# Amount of requests created: 399833 0.9995825
# Amount of requests created: 399895 0.9997375
# Amount of requests created: 399966 0.999915
# Amount of requests created: 400000 1.0
# 400000

# %% [markdown]
# ### Save to CSV

# %%
columns_to_export = ['Time', 'Username', 'Password', 'Useragent', 'Outcome']
generated_requests.to_csv('generated2.csv', columns=columns_to_export, index=False)
generated_requests_mal.to_csv('generated_malicious2.csv', columns=columns_to_export, index=False)

# %% [markdown]
# # Normal to 1NF

# %%
from user_agents import parse

# %%
def split_ua(ua):
    ua = parse(ua)
    return [ua.browser.family, ua.browser.version_string,ua.device.family,ua.device.brand, ua.device.model, ua.os.family,ua.os.version_string]

# %%
datas = pd.read_csv('generated2.csv')
datas
# Out:
#            Time          Username   Password  \
# 0             0           cole_ya    pokemon
# 1             0            skibo_   02012006
# 2             1   AmazonianNewbie   rushhour
# 3             2    TheDanimal8888     azerty
# 4             2  BleachedSkeleton    nathan8
# ...         ...               ...        ...
# 1999995  499999     sadlyEgyptian  agnieszka
# 1999996  499999  loved1youarewith   westside
# 1999997  499999         JustADood   24111982
# 1999998  499999         cumspaces     110966
# 1999999  499999   paddlethesaddle     fresh1
#
#                                                  Useragent  Outcome
# 0        Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...  Success
# 1        Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6...  Success
# 2        Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6...  Success
# 3        Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_3...  Success
# 4        Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_3...  Success
# ...                                                    ...      ...
# 1999995  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...  Success
# 1999996  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...  Success
# 1999997  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...  Success
# 1999998  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...  Success
# 1999999  Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebK...  Success
#
# [2000000 rows x 5 columns]

# %%
splitted_ua = pd.DataFrame(datas['Useragent'].apply(split_ua).values.tolist(), columns=['Browser Family', 'Browser Version', 'Device Family', 'Device Brand', 'Device Model','OS Family', 'OS Version'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-f3d204e398c2> in <module>
# ----> 1 splitted_ua = pd.DataFrame(datas['Useragent'].apply(split_ua).values.tolist(), columns=['Browser Family', 'Browser Version', 'Device Family', 'Device Brand', 'Device Model','OS Family', 'OS Version'])
#
# NameError: name 'pd' is not defined

# %%
data_w_splitted_ua = pd.concat([datas, splitted_ua], axis=1).drop('Useragent', axis=1)

# %%
columns_to_export = ['Time', 'Username', 'Password', 'Outcome', 'Browser Family', 'Browser Version', 'Device Family', 'Device Brand', 'Device Model','OS Family', 'OS Version']
data_w_splitted_ua.to_csv('generated2_ua_splitted.csv', columns=columns_to_export, index=False)
